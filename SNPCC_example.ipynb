# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %matplotlib inline
import matplotlib.pylab as plt
from os import listdir
from os.path import isfile, join, exists
# %aimport lc_parser

# %%
data_path = 'data/'
lc_list = [f for f in sorted(listdir(data_path)) if isfile(join(data_path, f)) and f.endswith('.DAT')]
N = len(lc_list)
print("%d .DAT files in data path" %(N))
name = lc_list[0]

lc, photoz, sn_class, sn_class_train = lc_parser.read_snpcc_lc(name, data_path)
print("Selected light curve: %s, type %s Supernovae"  %(name, sn_class))
lc_parser.plot_snpcc_lc(lc)
# Out:
# 5 .DAT files in data path
# Selected light curve: DES_SN000017.DAT, type II Supernovae
